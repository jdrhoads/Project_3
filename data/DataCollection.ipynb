# %%
import json
import numpy as np
import os
import pandas as pd
import urllib3
import requests
from pprint import pprint
from config import API_KEY
from config import API_SECRET
from config import API_PASS
auth = (API_KEY, API_SECRET, API_PASS)

# %%
coins = ['BTC_BTS', 'BTC_DASH', 'BTC_DOGE', 'BTC_LTC', 'BTC_NXT', 'BTC_STR', 'BTC_XEM', 'BTC_XMR', 'BTC_XRP', 'USDT_BTC', 'USDT_DASH', 'USDT_LTC', 'USDT_STR', 'USDT_XMR', 'USDT_XRP', 'BTC_ETH', 'USDT_ETH', 'BTC_SC', 'BTC_DCR', 'BTC_LSK', 'BTC_STEEM', 'BTC_ETC', 'ETH_ETC', 'USDT_ETC', 'BTC_ARDR', 'BTC_ZEC', 'ETH_ZEC', 'USDT_ZEC', 'BTC_ZRX', 'ETH_ZRX', 'BTC_CVC', 'BTC_OMG', 'BTC_GAS', 'BTC_STORJ', 'BTC_EOS', 'ETH_EOS', 'USDT_EOS', 'BTC_SNT', 'BTC_KNC', 'BTC_BAT', 'USDT_BAT', 'BTC_LOOM', 'USDT_DOGE', 'USDT_LSK', 'USDT_SC', 'USDT_ZRX', 'BTC_QTUM', 'USDT_QTUM', 'USDC_BTC', 'USDC_ETH', 'USDC_USDT', 'BTC_MANA', 'USDT_MANA', 'BTC_BNT', 'BTC_BCHSV', 'USDC_BCHSV', 'USDC_XRP', 'USDC_XMR', 'USDC_STR', 'USDC_DOGE', 'USDC_LTC', 'USDC_ZEC', 'BTC_FOAM', 'BTC_NMR', 'BTC_POLY', 'BTC_LPT', 'BTC_ATOM', 'USDC_ATOM', 'USDT_ATOM', 'USDC_DASH', 'USDC_EOS', 'USDC_ETC', 'USDT_BCHSV', 'BTC_TRX', 'USDC_TRX', 'USDT_TRX', 'TRX_ETH', 'TRX_XRP', 'USDT_BTT', 'TRX_BTT', 'USDT_WIN', 'TRX_WIN', 'TRX_STEEM', 'BTC_LINK', 'TRX_LINK', 'BTC_XTZ', 'USDT_XTZ', 'TRX_XTZ', 'USDT_BEAR', 'USDT_BULL', 'USDT_TRXBEAR', 'USDT_TRXBULL', 'PAX_BTC', 'PAX_ETH', 'USDT_PAX', 'USDT_USDJ', 'USDJ_BTC', 'USDJ_TRX', 'BTC_SNX', 'USDT_SNX', 'TRX_SNX', 'USDT_BSVBEAR', 'USDT_BSVBULL', 'BTC_MATIC', 'USDT_MATIC', 'TRX_MATIC', 'USDT_BCHBEAR', 'USDT_BCHBULL', 'USDT_ETHBEAR', 'USDT_ETHBULL', 'BTC_MKR', 'USDT_MKR', 'USDT_BVOL', 'USDT_IBVOL', 'DAI_BTC', 'DAI_ETH', 'USDT_DAI', 'BTC_NEO', 'USDT_NEO', 'TRX_NEO', 'BTC_SWFTC', 'USDT_SWFTC', 'TRX_SWFTC', 'USDT_JST', 'TRX_JST', 'USDT_BCN', 'USDT_STEEM', 'USDT_LINK', 'USDJ_BTT', 'BTC_AVA', 'USDT_AVA', 'TRX_AVA', 'USDT_XRPBULL', 'USDT_XRPBEAR', 'USDT_EOSBULL', 'USDT_EOSBEAR', 'USDT_LINKBULL', 'USDT_LINKBEAR', 'BTC_CHR', 'USDT_CHR', 'TRX_CHR', 'BNB_BTC', 'USDT_BNB', 'USDT_BUSD', 'TRX_BNB', 'BUSD_BNB', 'BUSD_BTC', 'BTC_MDT', 'USDT_MDT', 'TRX_MDT', 'USDT_BCHC', 'USDT_COMP', 'ETH_COMP', 'BTC_XFIL', 'USDT_XFIL', 'USDT_CUSDT', 'BTC_REN', 'USDT_REN', 'BTC_LRC', 'USDT_LRC', 'USDT_BAL', 'BTC_WRX', 'USDT_WRX', 'TRX_WRX', 'USDT_STAKE', 'USDT_BZRX', 'BTC_SXP', 'USDT_SXP', 'TRX_SXP', 'USDT_MTA', 'USDT_YFI', 'BTC_STPT', 'USDT_STPT', 'USDT_DEC', 'USDT_PLT', 'USDT_UMA', 'USDT_KTON', 'USDT_RING', 'BTC_SWAP', 'USDT_SWAP', 'USDT_TEND', 'BTC_EXE', 'USDT_EXE', 'USDT_TRADE', 'USDT_GEEQ', 'USDT_BAND', 'USDT_DOS', 'USDT_DIA', 'USDT_ZAP', 'USDT_PERX', 'USDT_TRB', 'USDT_DEXT', 'USDT_MCB', 'USDT_CRV', 'USDT_OM', 'USDT_OCEAN', 'USDT_BLY', 'BTC_SWINGBY', 'USDT_SWINGBY', 'TRX_SWINGBY', 'USDT_PRQ', 'USDT_DOT', 'BTC_DMG', 'USDT_DMG', 'TRX_DMG', 'USDT_RSR', 'USDT_WNXM', 'USDT_FCT2', 'BTC_FCT2', 'USDT_SUSHI', 'USDT_YFII', 'USDT_YFL', 'USDT_TAI', 'USDT_PEARL', 'USDT_JFI', 'USDT_CORN', 'USDT_SWRV', 'USDT_FSW', 'USDT_FUND', 'TRX_FUND', 'BTC_FUND', 'USDT_CREAM', 'USDT_SUN', 'USDT_HGET', 'BTC_HGET', 'USDT_AKRO', 'BTC_AKRO', 'USDT_ADEL', 'USDT_UNI', 'USDT_DHT', 'USDT_MEME', 'USDT_CVP', 'USDT_GHST', 'BTC_REPV2', 'USDT_REPV2', 'USDT_RARI', 'USDT_DICE', 'TRX_DICE', 'BTC_AMP', 'USDT_AMP', 'TRX_AMP', 'BTC_SAND', 'USDT_SAND', 'USDT_RFUEL', 'USDT_VALUE', 'USDT_POLS', 'BTC_AAVE', 'USDT_AAVE', 'BTC_BCHA', 'USDT_BCHA', 'BTC_BID', 'USDT_BID', 'BTC_CVT', 'USDT_CVT', 'BTC_INJ', 'USDT_INJ', 'BTC_BCH', 'USDT_BCH', 'USDC_BCH', 'BTC_SENSO', 'USDT_SENSO', 'USDT_KP3R', 'USDT_MPH', 'BTC_GLM', 'USDT_GLM', 'USDT_HEGIC', 'USDT_ZLOT', 'BTC_WBTC', 'USDT_WBTC', 'USDT_NU', 'BTC_FRONT', 'USDT_FRONT', 'USDT_API3', 'USDT_COVER', 'USDT_BADGER', 'BTC_FARM', 'USDT_FARM', 'BTC_DOT', 'USDT_GRT', 'TRX_SUN', 'USDT_XFLR', 'USDT_ESD', 'USDT_ONEINCH', 'USDT_REEF', 'USDT_BAS', 'USDT_BAC', 'USDT_LON', 'USDT_ROOK', 'USDT_TRU', 'USDT_CUDOS', 'USDT_BOND', 'USDT_PBTC35A', 'USDT_COMBO', 'USDT_TUSD', 'USDC_TUSD', 'USDT_ADABEAR', 'USDT_ADABULL', 'USDT_LTCBEAR', 'USDT_LTCBULL', 'USDT_XLMBEAR', 'USDT_XLMBULL', 'USDT_WETH', 'BTC_TRU', 'USDT_FTT', 'USDT_SRM', 'USDT_LPT', 'totalBNB', 'totalBTC', 'totalBUSD', 'totalDAI', 'totalETH', 'totalPAX', 'totalTRX', 'totalTUSD', 'totalUSDC', 'totalUSDJ', 'totalUSDT', 'totalXMR', 'totalXUSD']
df_list=[]
for coin in coins:
    url = "https://poloniex.com/public?command=returnTradeHistory&currencyPair=BTC_ETH&start=1610499341&end=1610499372"
    #'https://api-public.sandbox.pro.coinbase.com'
    #'https://poloniex.com/public?command=return24hVolume'
    r = requests.get(url)
    d = r.json()
    #openUrl.close()
    pprint(d)
# Out:
# [{'amount': '0.01474441',
#   'date': '2021-01-13 00:56:11',
#   'globalTradeID': 508982119,
#   'orderNumber': 822463283578,
#   'rate': '0.03065614',
#   'total': '0.00045200',
#   'tradeID': 51253418,
#   'type': 'sell'}]
# [{'amount': '0.01474441',
#   'date': '2021-01-13 00:56:11',
#   'globalTradeID': 508982119,
#   'orderNumber': 822463283578,
#   'rate': '0.03065614',
#   'total': '0.00045200',
#   'tradeID': 51253418,
#   'type': 'sell'}]
# [{'amount': '0.01474441',
#   'date': '2021-01-13 00:56:11',
#   'globalTradeID': 508982119,
#   'orderNumber': 822463283578,
#   'rate': '0.03065614',
#   'total': '0.00045200',
#   'tradeID': 51253418,
#   'type': 'sell'}]
# [{'amount': '0.01474441',
#   'date': '2021-01-13 00:56:11',
#   'globalTradeID': 508982119,
#   'orderNumber': 822463283578,
#   'rate': '0.03065614',
#   'total': '0.00045200',
#   'tradeID': 51253418,
#   'type': 'sell'}]
# [{'amount': '0.01474441',
#   'date': '2021-01-13 00:56:11',
# ...

# %%
d.keys()
# Out:
# dict_keys(['BTC_BTS', 'BTC_DASH', 'BTC_DOGE', 'BTC_LTC', 'BTC_NXT', 'BTC_STR', 'BTC_XEM', 'BTC_XMR', 'BTC_XRP', 'USDT_BTC', 'USDT_DASH', 'USDT_LTC', 'USDT_STR', 'USDT_XMR', 'USDT_XRP', 'BTC_ETH', 'USDT_ETH', 'BTC_SC', 'BTC_DCR', 'BTC_LSK', 'BTC_STEEM', 'BTC_ETC', 'ETH_ETC', 'USDT_ETC', 'BTC_ARDR', 'BTC_ZEC', 'ETH_ZEC', 'USDT_ZEC', 'BTC_ZRX', 'ETH_ZRX', 'BTC_CVC', 'BTC_OMG', 'BTC_GAS', 'BTC_STORJ', 'BTC_EOS', 'ETH_EOS', 'USDT_EOS', 'BTC_SNT', 'BTC_KNC', 'BTC_BAT', 'USDT_BAT', 'BTC_LOOM', 'USDT_DOGE', 'USDT_LSK', 'USDT_SC', 'USDT_ZRX', 'BTC_QTUM', 'USDT_QTUM', 'USDC_BTC', 'USDC_ETH', 'USDC_USDT', 'BTC_MANA', 'USDT_MANA', 'BTC_BNT', 'BTC_BCHSV', 'USDC_BCHSV', 'USDC_XRP', 'USDC_XMR', 'USDC_STR', 'USDC_DOGE', 'USDC_LTC', 'USDC_ZEC', 'BTC_FOAM', 'BTC_NMR', 'BTC_POLY', 'BTC_LPT', 'BTC_ATOM', 'USDC_ATOM', 'USDT_ATOM', 'USDC_DASH', 'USDC_EOS', 'USDC_ETC', 'USDT_BCHSV', 'BTC_TRX', 'USDC_TRX', 'USDT_TRX', 'TRX_ETH', 'TRX_XRP', 'USDT_BTT', 'TRX_BTT', 'USDT_WIN', 'TRX_WIN', 'TRX_STEEM', 'BTC_LINK
# ...

# %%
coins = ['BTC_BTS', 'BTC_DASH', 'BTC_DOGE', 'BTC_LTC', 'BTC_NXT', 'BTC_STR', 'BTC_XEM', 'BTC_XMR', 'BTC_XRP', 'USDT_BTC', 'USDT_DASH', 'USDT_LTC', 'USDT_STR', 'USDT_XMR', 'USDT_XRP', 'BTC_ETH', 'USDT_ETH', 'BTC_SC', 'BTC_DCR', 'BTC_LSK', 'BTC_STEEM', 'BTC_ETC', 'ETH_ETC', 'USDT_ETC', 'BTC_ARDR', 'BTC_ZEC', 'ETH_ZEC', 'USDT_ZEC', 'BTC_ZRX', 'ETH_ZRX', 'BTC_CVC', 'BTC_OMG', 'BTC_GAS', 'BTC_STORJ', 'BTC_EOS', 'ETH_EOS', 'USDT_EOS', 'BTC_SNT', 'BTC_KNC', 'BTC_BAT', 'USDT_BAT', 'BTC_LOOM', 'USDT_DOGE', 'USDT_LSK', 'USDT_SC', 'USDT_ZRX', 'BTC_QTUM', 'USDT_QTUM', 'USDC_BTC', 'USDC_ETH', 'USDC_USDT', 'BTC_MANA', 'USDT_MANA', 'BTC_BNT', 'BTC_BCHSV', 'USDC_BCHSV', 'USDC_XRP', 'USDC_XMR', 'USDC_STR', 'USDC_DOGE', 'USDC_LTC', 'USDC_ZEC', 'BTC_FOAM', 'BTC_NMR', 'BTC_POLY', 'BTC_LPT', 'BTC_ATOM', 'USDC_ATOM', 'USDT_ATOM', 'USDC_DASH', 'USDC_EOS', 'USDC_ETC', 'USDT_BCHSV', 'BTC_TRX', 'USDC_TRX', 'USDT_TRX', 'TRX_ETH', 'TRX_XRP', 'USDT_BTT', 'TRX_BTT', 'USDT_WIN', 'TRX_WIN', 'TRX_STEEM', 'BTC_LINK', 'TRX_LINK', 'BTC_XTZ', 'USDT_XTZ', 'TRX_XTZ', 'USDT_BEAR', 'USDT_BULL', 'USDT_TRXBEAR', 'USDT_TRXBULL', 'PAX_BTC', 'PAX_ETH', 'USDT_PAX', 'USDT_USDJ', 'USDJ_BTC', 'USDJ_TRX', 'BTC_SNX', 'USDT_SNX', 'TRX_SNX', 'USDT_BSVBEAR', 'USDT_BSVBULL', 'BTC_MATIC', 'USDT_MATIC', 'TRX_MATIC', 'USDT_BCHBEAR', 'USDT_BCHBULL', 'USDT_ETHBEAR', 'USDT_ETHBULL', 'BTC_MKR', 'USDT_MKR', 'USDT_BVOL', 'USDT_IBVOL', 'DAI_BTC', 'DAI_ETH', 'USDT_DAI', 'BTC_NEO', 'USDT_NEO', 'TRX_NEO', 'BTC_SWFTC', 'USDT_SWFTC', 'TRX_SWFTC', 'USDT_JST', 'TRX_JST', 'USDT_BCN', 'USDT_STEEM', 'USDT_LINK', 'USDJ_BTT', 'BTC_AVA', 'USDT_AVA', 'TRX_AVA', 'USDT_XRPBULL', 'USDT_XRPBEAR', 'USDT_EOSBULL', 'USDT_EOSBEAR', 'USDT_LINKBULL', 'USDT_LINKBEAR', 'BTC_CHR', 'USDT_CHR', 'TRX_CHR', 'BNB_BTC', 'USDT_BNB', 'USDT_BUSD', 'TRX_BNB', 'BUSD_BNB', 'BUSD_BTC', 'BTC_MDT', 'USDT_MDT', 'TRX_MDT', 'USDT_BCHC', 'USDT_COMP', 'ETH_COMP', 'BTC_XFIL', 'USDT_XFIL', 'USDT_CUSDT', 'BTC_REN', 'USDT_REN', 'BTC_LRC', 'USDT_LRC', 'USDT_BAL', 'BTC_WRX', 'USDT_WRX', 'TRX_WRX', 'USDT_STAKE', 'USDT_BZRX', 'BTC_SXP', 'USDT_SXP', 'TRX_SXP', 'USDT_MTA', 'USDT_YFI', 'BTC_STPT', 'USDT_STPT', 'USDT_DEC', 'USDT_PLT', 'USDT_UMA', 'USDT_KTON', 'USDT_RING', 'BTC_SWAP', 'USDT_SWAP', 'USDT_TEND', 'BTC_EXE', 'USDT_EXE', 'USDT_TRADE', 'USDT_GEEQ', 'USDT_BAND', 'USDT_DOS', 'USDT_DIA', 'USDT_ZAP', 'USDT_PERX', 'USDT_TRB', 'USDT_DEXT', 'USDT_MCB', 'USDT_CRV', 'USDT_OM', 'USDT_OCEAN', 'USDT_BLY', 'BTC_SWINGBY', 'USDT_SWINGBY', 'TRX_SWINGBY', 'USDT_PRQ', 'USDT_DOT', 'BTC_DMG', 'USDT_DMG', 'TRX_DMG', 'USDT_RSR', 'USDT_WNXM', 'USDT_FCT2', 'BTC_FCT2', 'USDT_SUSHI', 'USDT_YFII', 'USDT_YFL', 'USDT_TAI', 'USDT_PEARL', 'USDT_JFI', 'USDT_CORN', 'USDT_SWRV', 'USDT_FSW', 'USDT_FUND', 'TRX_FUND', 'BTC_FUND', 'USDT_CREAM', 'USDT_SUN', 'USDT_HGET', 'BTC_HGET', 'USDT_AKRO', 'BTC_AKRO', 'USDT_ADEL', 'USDT_UNI', 'USDT_DHT', 'USDT_MEME', 'USDT_CVP', 'USDT_GHST', 'BTC_REPV2', 'USDT_REPV2', 'USDT_RARI', 'USDT_DICE', 'TRX_DICE', 'BTC_AMP', 'USDT_AMP', 'TRX_AMP', 'BTC_SAND', 'USDT_SAND', 'USDT_RFUEL', 'USDT_VALUE', 'USDT_POLS', 'BTC_AAVE', 'USDT_AAVE', 'BTC_BCHA', 'USDT_BCHA', 'BTC_BID', 'USDT_BID', 'BTC_CVT', 'USDT_CVT', 'BTC_INJ', 'USDT_INJ', 'BTC_BCH', 'USDT_BCH', 'USDC_BCH', 'BTC_SENSO', 'USDT_SENSO', 'USDT_KP3R', 'USDT_MPH', 'BTC_GLM', 'USDT_GLM', 'USDT_HEGIC', 'USDT_ZLOT', 'BTC_WBTC', 'USDT_WBTC', 'USDT_NU', 'BTC_FRONT', 'USDT_FRONT', 'USDT_API3', 'USDT_COVER', 'USDT_BADGER', 'BTC_FARM', 'USDT_FARM', 'BTC_DOT', 'USDT_GRT', 'TRX_SUN', 'USDT_XFLR', 'USDT_ESD', 'USDT_ONEINCH', 'USDT_REEF', 'USDT_BAS', 'USDT_BAC', 'USDT_LON', 'USDT_ROOK', 'USDT_TRU', 'USDT_CUDOS', 'USDT_BOND', 'USDT_PBTC35A', 'USDT_COMBO', 'USDT_TUSD', 'USDC_TUSD', 'USDT_ADABEAR', 'USDT_ADABULL', 'USDT_LTCBEAR', 'USDT_LTCBULL', 'USDT_XLMBEAR', 'USDT_XLMBULL', 'USDT_WETH', 'BTC_TRU', 'USDT_FTT', 'USDT_SRM', 'USDT_LPT', 'totalBNB', 'totalBTC', 'totalBUSD', 'totalDAI', 'totalETH', 'totalPAX', 'totalTRX', 'totalTUSD', 'totalUSDC', 'totalUSDJ', 'totalUSDT', 'totalXMR', 'totalXUSD']
#df_list=[]
for coin in coins:
    url = 'https://api.pro.coinbase.com/time?=auth'
    #'https://api-public.sandbox.pro.coinbase.com'
    #'https://poloniex.com/public?command=return24hVolume'
    r = requests.get(url)
    d = r.json()
    #openUrl.close()
    pprint(d)
# Out:
# {'epoch': 1612240738.149, 'iso': '2021-02-02T04:38:58.149Z'}
# {'epoch': 1612240738.509, 'iso': '2021-02-02T04:38:58.509Z'}
# {'epoch': 1612240738.795, 'iso': '2021-02-02T04:38:58.795Z'}
# {'epoch': 1612240739.109, 'iso': '2021-02-02T04:38:59.109Z'}
# {'epoch': 1612240739.448, 'iso': '2021-02-02T04:38:59.448Z'}
# {'epoch': 1612240739.813, 'iso': '2021-02-02T04:38:59.813Z'}
# {'epoch': 1612240740.059, 'iso': '2021-02-02T04:39:00.059Z'}
# {'epoch': 1612240740.346, 'iso': '2021-02-02T04:39:00.346Z'}
# {'epoch': 1612240740.657, 'iso': '2021-02-02T04:39:00.657Z'}
# {'epoch': 1612240741.078, 'iso': '2021-02-02T04:39:01.078Z'}
# {'epoch': 1612240741.343, 'iso': '2021-02-02T04:39:01.343Z'}
# {'epoch': 1612240741.64, 'iso': '2021-02-02T04:39:01.64Z'}
# {'epoch': 1612240741.938, 'iso': '2021-02-02T04:39:01.938Z'}
# {'epoch': 1612240742.239, 'iso': '2021-02-02T04:39:02.239Z'}
# {'epoch': 1612240742.958, 'iso': '2021-02-02T04:39:02.958Z'}
# ...

# %%
coins = ['BTC_BTS', 'BTC_DASH', 'BTC_DOGE', 'BTC_LTC', 'BTC_NXT', 'BTC_STR', 'BTC_XEM', 'BTC_XMR', 'BTC_XRP', 'USDT_BTC', 'USDT_DASH', 'USDT_LTC', 'USDT_STR', 'USDT_XMR', 'USDT_XRP', 'BTC_ETH', 'USDT_ETH', 'BTC_SC', 'BTC_DCR', 'BTC_LSK', 'BTC_STEEM', 'BTC_ETC', 'ETH_ETC', 'USDT_ETC', 'BTC_ARDR', 'BTC_ZEC', 'ETH_ZEC', 'USDT_ZEC', 'BTC_ZRX', 'ETH_ZRX', 'BTC_CVC', 'BTC_OMG', 'BTC_GAS', 'BTC_STORJ', 'BTC_EOS', 'ETH_EOS', 'USDT_EOS', 'BTC_SNT', 'BTC_KNC', 'BTC_BAT', 'USDT_BAT', 'BTC_LOOM', 'USDT_DOGE', 'USDT_LSK', 'USDT_SC', 'USDT_ZRX', 'BTC_QTUM', 'USDT_QTUM', 'USDC_BTC', 'USDC_ETH', 'USDC_USDT', 'BTC_MANA', 'USDT_MANA', 'BTC_BNT', 'BTC_BCHSV', 'USDC_BCHSV', 'USDC_XRP', 'USDC_XMR', 'USDC_STR', 'USDC_DOGE', 'USDC_LTC', 'USDC_ZEC', 'BTC_FOAM', 'BTC_NMR', 'BTC_POLY', 'BTC_LPT', 'BTC_ATOM', 'USDC_ATOM', 'USDT_ATOM', 'USDC_DASH', 'USDC_EOS', 'USDC_ETC', 'USDT_BCHSV', 'BTC_TRX', 'USDC_TRX', 'USDT_TRX', 'TRX_ETH', 'TRX_XRP', 'USDT_BTT', 'TRX_BTT', 'USDT_WIN', 'TRX_WIN', 'TRX_STEEM', 'BTC_LINK', 'TRX_LINK', 'BTC_XTZ', 'USDT_XTZ', 'TRX_XTZ', 'USDT_BEAR', 'USDT_BULL', 'USDT_TRXBEAR', 'USDT_TRXBULL', 'PAX_BTC', 'PAX_ETH', 'USDT_PAX', 'USDT_USDJ', 'USDJ_BTC', 'USDJ_TRX', 'BTC_SNX', 'USDT_SNX', 'TRX_SNX', 'USDT_BSVBEAR', 'USDT_BSVBULL', 'BTC_MATIC', 'USDT_MATIC', 'TRX_MATIC', 'USDT_BCHBEAR', 'USDT_BCHBULL', 'USDT_ETHBEAR', 'USDT_ETHBULL', 'BTC_MKR', 'USDT_MKR', 'USDT_BVOL', 'USDT_IBVOL', 'DAI_BTC', 'DAI_ETH', 'USDT_DAI', 'BTC_NEO', 'USDT_NEO', 'TRX_NEO', 'BTC_SWFTC', 'USDT_SWFTC', 'TRX_SWFTC', 'USDT_JST', 'TRX_JST', 'USDT_BCN', 'USDT_STEEM', 'USDT_LINK', 'USDJ_BTT', 'BTC_AVA', 'USDT_AVA', 'TRX_AVA', 'USDT_XRPBULL', 'USDT_XRPBEAR', 'USDT_EOSBULL', 'USDT_EOSBEAR', 'USDT_LINKBULL', 'USDT_LINKBEAR', 'BTC_CHR', 'USDT_CHR', 'TRX_CHR', 'BNB_BTC', 'USDT_BNB', 'USDT_BUSD', 'TRX_BNB', 'BUSD_BNB', 'BUSD_BTC', 'BTC_MDT', 'USDT_MDT', 'TRX_MDT', 'USDT_BCHC', 'USDT_COMP', 'ETH_COMP', 'BTC_XFIL', 'USDT_XFIL', 'USDT_CUSDT', 'BTC_REN', 'USDT_REN', 'BTC_LRC', 'USDT_LRC', 'USDT_BAL', 'BTC_WRX', 'USDT_WRX', 'TRX_WRX', 'USDT_STAKE', 'USDT_BZRX', 'BTC_SXP', 'USDT_SXP', 'TRX_SXP', 'USDT_MTA', 'USDT_YFI', 'BTC_STPT', 'USDT_STPT', 'USDT_DEC', 'USDT_PLT', 'USDT_UMA', 'USDT_KTON', 'USDT_RING', 'BTC_SWAP', 'USDT_SWAP', 'USDT_TEND', 'BTC_EXE', 'USDT_EXE', 'USDT_TRADE', 'USDT_GEEQ', 'USDT_BAND', 'USDT_DOS', 'USDT_DIA', 'USDT_ZAP', 'USDT_PERX', 'USDT_TRB', 'USDT_DEXT', 'USDT_MCB', 'USDT_CRV', 'USDT_OM', 'USDT_OCEAN', 'USDT_BLY', 'BTC_SWINGBY', 'USDT_SWINGBY', 'TRX_SWINGBY', 'USDT_PRQ', 'USDT_DOT', 'BTC_DMG', 'USDT_DMG', 'TRX_DMG', 'USDT_RSR', 'USDT_WNXM', 'USDT_FCT2', 'BTC_FCT2', 'USDT_SUSHI', 'USDT_YFII', 'USDT_YFL', 'USDT_TAI', 'USDT_PEARL', 'USDT_JFI', 'USDT_CORN', 'USDT_SWRV', 'USDT_FSW', 'USDT_FUND', 'TRX_FUND', 'BTC_FUND', 'USDT_CREAM', 'USDT_SUN', 'USDT_HGET', 'BTC_HGET', 'USDT_AKRO', 'BTC_AKRO', 'USDT_ADEL', 'USDT_UNI', 'USDT_DHT', 'USDT_MEME', 'USDT_CVP', 'USDT_GHST', 'BTC_REPV2', 'USDT_REPV2', 'USDT_RARI', 'USDT_DICE', 'TRX_DICE', 'BTC_AMP', 'USDT_AMP', 'TRX_AMP', 'BTC_SAND', 'USDT_SAND', 'USDT_RFUEL', 'USDT_VALUE', 'USDT_POLS', 'BTC_AAVE', 'USDT_AAVE', 'BTC_BCHA', 'USDT_BCHA', 'BTC_BID', 'USDT_BID', 'BTC_CVT', 'USDT_CVT', 'BTC_INJ', 'USDT_INJ', 'BTC_BCH', 'USDT_BCH', 'USDC_BCH', 'BTC_SENSO', 'USDT_SENSO', 'USDT_KP3R', 'USDT_MPH', 'BTC_GLM', 'USDT_GLM', 'USDT_HEGIC', 'USDT_ZLOT', 'BTC_WBTC', 'USDT_WBTC', 'USDT_NU', 'BTC_FRONT', 'USDT_FRONT', 'USDT_API3', 'USDT_COVER', 'USDT_BADGER', 'BTC_FARM', 'USDT_FARM', 'BTC_DOT', 'USDT_GRT', 'TRX_SUN', 'USDT_XFLR', 'USDT_ESD', 'USDT_ONEINCH', 'USDT_REEF', 'USDT_BAS', 'USDT_BAC', 'USDT_LON', 'USDT_ROOK', 'USDT_TRU', 'USDT_CUDOS', 'USDT_BOND', 'USDT_PBTC35A', 'USDT_COMBO', 'USDT_TUSD', 'USDC_TUSD', 'USDT_ADABEAR', 'USDT_ADABULL', 'USDT_LTCBEAR', 'USDT_LTCBULL', 'USDT_XLMBEAR', 'USDT_XLMBULL', 'USDT_WETH', 'BTC_TRU', 'USDT_FTT', 'USDT_SRM', 'USDT_LPT', 'totalBNB', 'totalBTC', 'totalBUSD', 'totalDAI', 'totalETH', 'totalPAX', 'totalTRX', 'totalTUSD', 'totalUSDC', 'totalUSDJ', 'totalUSDT', 'totalXMR', 'totalXUSD']
df_list=[]
for coin in coins:
    url = "https://poloniex.com/public?command=returnChartData&currencyPair=totalBTC&start=1546300800&end=1546646400&period=14400"
    #'https://api-public.sandbox.pro.coinbase.com'
    #'https://poloniex.com/public?command=return24hVolume'
    r = requests.get(url)
    d = r.json()
    #openUrl.close()
    pprint(d)


# coin_data = pd.DataFrame(d)
# output_file = os.path.join("result", "ChartData.csv")

# coin_data.to_csv(output_file)
# coin_data.head(10000)
# Out:
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# {'error': 'Invalid currency pair.'}
# ...

# %%
coin_data = pd.DataFrame(d)
output_file = os.path.join("result", "ChartData.csv")

coin_data.to_csv(output_file)
coin_data.head(10000)
# Out:
#           date      high       low      open     close      volume  \
# 0   1546300800  0.012322  0.012105  0.012274  0.012247   11.474740
# 1   1546315200  0.012358  0.012180  0.012254  0.012231    6.965434
# 2   1546329600  0.012342  0.012173  0.012231  0.012283    7.109577
# 3   1546344000  0.012380  0.012249  0.012292  0.012291    9.145455
# 4   1546358400  0.012458  0.012252  0.012280  0.012458   20.975012
# 5   1546372800  0.012648  0.012392  0.012429  0.012495   29.140455
# 6   1546387200  0.012600  0.012432  0.012495  0.012479   10.031364
# 7   1546401600  0.012784  0.012479  0.012479  0.012752   19.837235
# 8   1546416000  0.012865  0.012575  0.012752  0.012760   60.399254
# 9   1546430400  0.013176  0.012693  0.012760  0.013000   99.558344
# 10  1546444800  0.013921  0.012995  0.012995  0.013576  159.009184
# 11  1546459200  0.013800  0.013161  0.013576  0.013290   62.607227
# 12  1546473600  0.013369  0.013080  0.013290  0.013156   30.405676
# ...

# %%
pprint(coins)
# Out:
# ['BTC_BTS',
#  'BTC_DASH',
#  'BTC_DOGE',
#  'BTC_LTC',
#  'BTC_NXT',
#  'BTC_STR',
#  'BTC_XEM',
#  'BTC_XMR',
#  'BTC_XRP',
#  'USDT_BTC',
#  'USDT_DASH',
#  'USDT_LTC',
#  'USDT_STR',
#  'USDT_XMR',
#  'USDT_XRP',
#  'BTC_ETH',
#  'USDT_ETH',
#  'BTC_SC',
#  'BTC_DCR',
#  'BTC_LSK',
#  'BTC_STEEM',
#  'BTC_ETC',
#  'ETH_ETC',
#  'USDT_ETC',
#  'BTC_ARDR',
#  'BTC_ZEC',
#  'ETH_ZEC',
#  'USDT_ZEC',
#  'BTC_ZRX',
#  'ETH_ZRX',
#  'BTC_CVC',
#  'BTC_OMG',
#  'BTC_GAS',
#  'BTC_STORJ',
#  'BTC_EOS',
#  'ETH_EOS',
#  'USDT_EOS',
#  'BTC_SNT',
#  'BTC_KNC',
#  'BTC_BAT',
#  'USDT_BAT',
#  'BTC_LOOM',
#  'USDT_DOGE',
#  'USDT_LSK',
#  'USDT_SC',
#  'USDT_ZRX',
#  'BTC_QTUM',
#  'USDT_QTUM',
#  'USDC_BTC',
#  'USDC_ETH',
#  'USDC_USDT',
#  'BTC_MANA',
#  'USDT_MANA',
#  'BTC_BNT',
#  'BTC_BCHSV',
#  'USDC_BCHSV',
#  'USDC_XRP',
#  'USDC_XMR',
#  'USDC_STR',
#  'USDC_DOGE',
#  'USDC_LTC',
#  'USDC_ZEC',
#  'BTC_FOAM',
#  'BTC_NMR',
#  'BTC_POLY',
#  'BTC_LPT',
#  'BTC_ATOM',
# ...

# %%
coin_list = pd.DataFrame(coins)
coin_list.head(320)
# Out:
#              0
# 0      BTC_BTS
# 1     BTC_DASH
# 2     BTC_DOGE
# 3      BTC_LTC
# 4      BTC_NXT
# ..         ...
# 314  totalUSDC
# 315  totalUSDJ
# 316  totalUSDT
# 317   totalXMR
# 318  totalXUSD
#
# [319 rows x 1 columns]

# %%
coin_file = os.path.join("result", "CoinList.csv")

coin_list.to_csv(coin_file)

# %%
url = 'https://poloniex.com/public?command=returnChartData&currencyPair=USDT_ETH&start=1356998100&end=9999999999&period=300'
openUrl = urllib3.urlopen(url)
r = openUrl.read()
openUrl.close()
d = json.loads(r.decode())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-186-759b8e11d5a4> in <module>
#       1 url = 'https://poloniex.com/public?command=returnChartData&currencyPair=USDT_ETH&start=1356998100&end=9999999999&period=300'
# ----> 2 openUrl = urllib3.urlopen(url)
#       3 r = openUrl.read()
#       4 openUrl.close()
#       5 d = json.loads(r.decode())
#
# AttributeError: module 'urllib3' has no attribute 'urlopen'

# %%
df = pd.DataFrame()
# original_columns=[u'close', u'date', u'high', u'low', u'open']
# new_columns = ['Close','Timestamp','High','Low','Open']
# #df = df.loc[:,original_columns]
# df.columns = new_columns
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import h5py
with h5py.File(''.join(['data/bitcoin2015to2017_wf.h5']), 'r') as hf:
    datas = hf['inputs'].value
    labels = hf['outputs'].value
    input_times = hf['input_times'].value
    output_times = hf['output_times'].value
    original_inputs = hf['original_inputs'].value
    original_outputs = hf['original_outputs'].value
    original_datas = hf['original_datas'].value
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-144-b1f1ad51263a> in <module>
#       1 import h5py
# ----> 2 with h5py.File(''.join(['data/bitcoin2015to2017_wf.h5']), 'r') as hf:
#       3     datas = hf['inputs'].value
#       4     labels = hf['outputs'].value
#       5     input_times = hf['input_times'].value
#
# ~/opt/anaconda3/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404             with phil:
#     405                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
#     408                                swmr=swmr)
#
# ...

# %%
original_inputs[0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-145-f86e082ee5a6> in <module>
# ----> 1 original_inputs[0].shape
#
# NameError: name 'original_inputs' is not defined

# %%
df.to_csv('data/bitcoin2015to2017.csv',index=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-146-3e3bb43b6835> in <module>
# ----> 1 df.to_csv('data/bitcoin2015to2017.csv',index=None)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ...
